# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
model_directory = "/raid/s3/opengptx/mfrey/3.73T-Tokens/checkpoints"
# Load the tokenizer and model from the local directory
tokenizer = AutoTokenizer.from_pretrained(model_directory)
tokenizer.add_special_tokens({"pad_token": "[PAD]"})
tokenizer.add_special_tokens({"eos_token": "[EOS]"})
tokenizer.save_pretrained(model_directory)
# Out:
# ('/raid/s3/opengptx/mfrey/3.73T-Tokens/checkpoints/tokenizer_config.json',
#  '/raid/s3/opengptx/mfrey/3.73T-Tokens/checkpoints/special_tokens_map.json',
#  '/raid/s3/opengptx/mfrey/3.73T-Tokens/checkpoints/tokenizer.model',
#  '/raid/s3/opengptx/mfrey/3.73T-Tokens/checkpoints/added_tokens.json',
#  '/raid/s3/opengptx/mfrey/3.73T-Tokens/checkpoints/tokenizer.json')

# %%
from transformers import AutoTokenizer

# Use the same tokenizer path that lighteval would use for your model
tokenizer = AutoTokenizer.from_pretrained("/raid/s3/opengptx/mfrey/3.73T-Tokens/checkpoints/aug15_tokfix", trust_remote_code=True)

# %%
print(f"Tokenizer vocabulary size: {tokenizer.vocab_size}")
# Or, more robustly:
print(f"Length of tokenizer vocabulary: {len(tokenizer)}")
# Out:
# Tokenizer vocabulary size: 250880
# Length of tokenizer vocabulary: 250880

# %%
path = '/raid/s3/opengptx/mfrey/3.73T-Tokens/checkpoints'
model = AutoModelForCausalLM.from_pretrained(path, trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained(path)

# %%
# This will now work properly!
outputs = model.generate(tokenizer("Hello, how are you?", return_tensors="pt").input_ids)

# %%
from vllm import LLM

# %%
llm = LLM(
    model='/raid/s3/opengptx/mfrey/3.73T-Tokens/checkpoints',
    tensor_parallel_size=1,  # Disable TP first
    trust_remote_code=True   # If using custom model
    # Specify device,
    device='cuda:6'  # Uncomment if you want to specify a device
)
