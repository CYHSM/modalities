# %%
import os
os.environ["HF_HOME"] = "/raid/s3/opengptx/mfrey/huggingface"

from data import load_and_format_dataset

# %%
dataset = load_and_format_dataset(
    "nvidia/OpenMathInstruct-2",
    "train_1M",
    0.01,
    42,
)
# Out:
# Resolving data files:   0%|          | 0/32 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/32 [00:00<?, ?it/s]

# %%
dataset['train'][10]
# Out:
# {'messages': [{'content': 'Solve the following math problem. Explain your reasoning and put the final answer in \\boxed{}.\n\nSuppose that the roots of the equation $x^3 - 7x^2 + kx - m = 0$ are three distinct positive integers that form an arithmetic progression. Find the value of $k + 3m$.',
#    'role': 'user'},
#   {'content': "We are given that the roots of the equation form an arithmetic progression. Let the roots be $r - d$, $r$, and $r + d$, where $r$ is the middle root and $d$ is the common difference.\n\nThe sum of the roots is $7$:\n\\[ (r - d) + r + (r + d) = 7 \\Rightarrow 3r = 7 \\Rightarrow r = 7 : 3 \\Rightarrow r = 7/3 \\]\n\nSince the roots are integers, we can test the nearest integer values for $r$ that would result in an arithmetic progression.\n\nIf $r = 2$, the roots could be $1, 2, 3$. If $r = 3$, the roots could be $1, 3, 5$. We will test both cases.\n\nCase 1: $r = 2$, roots are $1, 2, 3$.\nSubstituting these roots into the original equation:\n\\[ x^3 - 7x^2 + kx - m = (x - 1)(x - 2)(x - 3) = x^3 - 6x^2 + 11x - 6 \\]\n\nComparing coefficients, we find that $k = 11$ and $m = 6$.\nThus, $k + 3m = 11 + 3(6) = 11 + 18 = 29$.\n\nCase 2: $r = 3$, roots are $1, 3, 5$.\nSubstituting these roots into the original equation:\n\\[ x^3 - 7x^2 + kx - m = (x - 1)(x - 3)(x - 5) = x^3 - 9x^2 + 23x - 15 \\]\n\nComparing coefficients, we find that $k = 23$ and $m = 15$.\nThus, $k + 3m = 23 + 3(15) = 23 + 45 = 68$.\n\nHowever, we notice that the given equation has the coefficient of $x^2$ as $-7$, which matches neither case exactly.\n\nBut, we can see that the roots $1, 2, 3$ give a coefficient of $-6$ for $x^2$, which is closer to $-7$ than the roots $1, 3, 5$.\n\nHowever, we see that for roots $1, 2, 3$, the equation becomes $x^3 - 6x^2 + 11x - 6 = 0$. We can try to adjust this equation to match the given equation.\n\nComparing with the given equation, we can adjust the roots slightly to fit.\n\nAfter testing, we find that the correct roots are $1, 2, 4$. Let's verify:\n\nThe equation with roots $1, 2, 4$ is:\n\\[ (x - 1)(x - 2)(x - 4) = x^3 - 7x^2 + 14x - 8 = 0 \\]\n\nComparing coefficients, we find that $k = 14$ and $m = 8$.\nThus, $k + 3m = 14 + 3(8) = 14 + 24 = 38$.\n\nSo, the answer is:\n\\[ \\boxed{38} \\]",
#    'role': 'assistant'}]}
